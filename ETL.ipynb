# %%
import pandas as pd
import numpy as np
import json

# %%
moviesdf = pd.read_csv('Dataset/movies_dataset.csv', low_memory=False)
moviesdf.head(5)
# Out:
#    adult                              belongs_to_collection    budget
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  \
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en  \
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title
# 0                    Toy Story  \
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30  \
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]  \
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline
# 0  Released                                                NaN  \
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
# Dimensiones del dataframe
moviesdf.shape
# Out:
# (45466, 24)

# %%
# Vemos informacion del dataframe
moviesdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
# Miramos cantidad de filas por columnas que tiene el dataframe
moviesdf.shape
# Out:
# (45466, 24)

# %%
# Miramos cantidad de valores nulos que tiene la columna belongs_to_collection'
moviesdf['belongs_to_collection'].isnull().sum()
# Out:
# 40972

# %%
# Imputamos los valores faltantes en la columna 'belongs_to_collection' con la cadena vacía ''
moviesdf['belongs_to_collection'].fillna('', inplace=True)

# %%
# Miramos los valores unicos de la columna a transformar
moviesdf['belongs_to_collection'].unique()
# Out:
# array(["{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}",
#        '',
#        "{'id': 119050, 'name': 'Grumpy Old Men Collection', 'poster_path': '/nLvUdqgPgm3F85NMCii9gVFUcet.jpg', 'backdrop_path': '/hypTnLot2z8wpFS7qwsQHW1uV8u.jpg'}",
#        ...,
#        "{'id': 148603, 'name': 'Ducobu Collection', 'poster_path': '/rd7AWZUy2QFPIblNWToVmdfXQcA.jpg', 'backdrop_path': '/7mzKmoIrvGapvsSbAVlX4HtCnFj.jpg'}",
#        "{'id': 152918, 'name': 'Mister Blot Collection', 'poster_path': '/44PYEwwjGts8pAob59RHd6zlkKc.jpg', 'backdrop_path': '/5uoPsNiFpUYNamSGqE8okN27VRK.jpg'}",
#        "{'id': 200641, 'name': 'Red Lotus Collection', 'poster_path': '/yf9Eod9ANXyHTzDpAxz9ezgvlL4.jpg', 'backdrop_path': '/3fhHbLeO3DqdHvgHg5szs399eBb.jpg'}"],
#       dtype=object)

# %%
# Observamos 5 valores aleatoros de nuestro dataset
moviesdf.sample(5)
# Out:
#        adult                              belongs_to_collection    budget
# 15357  False                                                      2000000  \
# 27944  False                                                            0
# 22104  False                                                            0
# 142    False  {'id': 14890, 'name': 'Bad Boys Collection', '...  19000000
# 33521  False                                                            0
#
#                                                   genres
# 15357                      [{'id': 18, 'name': 'Drama'}]  \
# 27944                      [{'id': 18, 'name': 'Drama'}]
# 22104  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 142    [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 33521                                                 []
#
#                                homepage     id    imdb_id original_language
# 15357  http://www.wintersbonemovie.com/  39013  tt1399683                en  \
# 27944                               NaN  88599  tt1754003                es
# 22104                               NaN  27294  tt0088963                en
# 142                                 NaN   9737  tt0112442                en
# 33521                               NaN  61829  tt0049634                it
#
#               original_title
# 15357          Winter's Bone  \
# 27944  Karen llora en un bus
# 22104             Crime Wave
# 142                 Bad Boys
# 33521        Poveri ma belli
#
#                                                 overview  ... release_date
# 15357  17 year-old Ree Dolly sets out to track down h...  ...   2010-06-11  \
# 27944  Karen discovers, after 10 years of marriage, s...  ...   2011-05-13
# 22104  A young director intent on making "the greates...  ...   1985-04-12
# 142    Marcus Burnett is a hen-pecked family man. Mik...  ...   1995-04-07
# 33521  Salvatore and Romolo are two young and poor yo...  ...   1957-12-30
#
#            revenue runtime                           spoken_languages
# 15357   13831503.0   100.0   [{'iso_639_1': 'en', 'name': 'English'}]  \
# 27944          0.0    98.0   [{'iso_639_1': 'es', 'name': 'Español'}]
# 22104          0.0    80.0   [{'iso_639_1': 'en', 'name': 'English'}]
# 142    141407024.0   118.0   [{'iso_639_1': 'en', 'name': 'English'}]
# 33521          0.0     0.0  [{'iso_639_1': 'it', 'name': 'Italiano'}]
#
#          status                        tagline                   title  video
# 15357  Released  Talking Just Causes Witnesses           Winter's Bone  False  \
# 27944  Released                            NaN  Karen Cries on the Bus  False
# 22104  Released          He was a quiet man...              Crime Wave  False
# 142    Released              Whatcha gonna do?                Bad Boys  False
# 33521  Released                            NaN      Poor But Beautiful  False
#
#       vote_average vote_count
# 15357          6.8      575.0
# 27944          7.5        4.0
# 22104          5.9        7.0
# 142            6.5     1729.0
# 33521          7.3       12.0
#
# [5 rows x 24 columns]

# %%
# Normalizamos primero las comillas para la columna belongs_to_collection:

import json

def fix_quotes(x):
    if pd.isnull(x):
        return x
    try:
        return json.loads(x.replace("'", '"'))
    except json.JSONDecodeError:
        return {}

moviesdf['belongs_to_collection'] = moviesdf['belongs_to_collection'].apply(fix_quotes)

# %%
# Este ciclo for imprime los nombres de las colecciones si existen y None si no hay una colección asociada a la película.

for collection in moviesdf['belongs_to_collection']:
    if collection is not None:
        print(collection.get('name'))

# %%
# Creamos una nueva columna en el dataframe llamada collection_name y le asignamos los valores de la colección en formato de cadena de caracteres

moviesdf['collection_name'] = moviesdf['belongs_to_collection'].apply(lambda x: x.get('name') if isinstance(x, dict) else None)

# %%
# De nuevo volvemos a ver informacion de los datos
moviesdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  45466 non-null  object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
#  24  collection_name        3168 non-null   object
# dtypes: float64(4), object(21)
# memory usage: 8.7+ MB

# %%
# Observamos si se creo la nueva columna,'collection_name'
moviesdf.head()
# Out:
#    adult                              belongs_to_collection    budget
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1  False                                                 {}  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                 {}  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  \
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en  \
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title
# 0                    Toy Story  \
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...      revenue
# 0  Led by Woody, Andy's toys live happily in his ...  ...  373554033.0  \
# 1  When siblings Judy and Peter discover an encha...  ...  262797249.0
# 2  A family wedding reignites the ancient feud be...  ...          0.0
# 3  Cheated on, mistreated and stepped on, the wom...  ...   81452156.0
# 4  Just when George Banks has recovered from his ...  ...   76578911.0
#
#   runtime                                   spoken_languages    status
# 0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released  \
# 1   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2   101.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3   127.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4   106.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline
# 0                                                NaN  \
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0  \
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
#                   collection_name
# 0            Toy Story Collection
# 1                            None
# 2       Grumpy Old Men Collection
# 3                            None
# 4  Father of the Bride Collection
#
# [5 rows x 25 columns]

# %%
# Eliminamos la columna belongs_to_collection, porque ya logramos con la nueva columna collection_name extraer y mostrar los nombres de las series
moviesdf = moviesdf.drop('belongs_to_collection', axis=1)

# %%
# De nuevo miramos los datos de los campos o columnas
moviesdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   adult                 45466 non-null  object
#  1   budget                45466 non-null  object
#  2   genres                45466 non-null  object
#  3   homepage              7782 non-null   object
#  4   id                    45466 non-null  object
#  5   imdb_id               45449 non-null  object
#  6   original_language     45455 non-null  object
#  7   original_title        45466 non-null  object
#  8   overview              44512 non-null  object
#  9   popularity            45461 non-null  object
#  10  poster_path           45080 non-null  object
#  11  production_companies  45463 non-null  object
#  12  production_countries  45463 non-null  object
#  13  release_date          45379 non-null  object
#  14  revenue               45460 non-null  float64
#  15  runtime               45203 non-null  float64
#  16  spoken_languages      45460 non-null  object
#  17  status                45379 non-null  object
#  18  tagline               20412 non-null  object
#  19  title                 45460 non-null  object
#  20  video                 45460 non-null  object
#  21  vote_average          45460 non-null  float64
#  22  vote_count            45460 non-null  float64
#  23  collection_name       3168 non-null   object
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
# Miramos el dataframe y observaos que la columna genres tiene datos tipo diccionario, que debenos transformar
moviesdf.head()
# Out:
#    adult    budget                                             genres
# 0  False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  \
# 1  False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4  False         0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en  \
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title
# 0                    Toy Story  \
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview popularity  ...
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943  ...  \
# 1  When siblings Judy and Peter discover an encha...  17.015539  ...
# 2  A family wedding reignites the ancient feud be...    11.7129  ...
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495  ...
# 4  Just when George Banks has recovered from his ...   8.387519  ...
#
#        revenue runtime                                   spoken_languages
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]  \
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline
# 0  Released                                                NaN  \
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0  \
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
#                   collection_name
# 0            Toy Story Collection
# 1                            None
# 2       Grumpy Old Men Collection
# 3                            None
# 4  Father of the Bride Collection
#
# [5 rows x 24 columns]

# %%
# Convertios las comillas simples en comillas dobles en la columna 'genres' del dataframe 'moviesdf', utilizando la biblioteca json. Luego aplicamos 
# la función 'get_genre_name' a la columna 'genres' para obtener el nombre del género en formato de cadena de texto separado por "|" en la nueva 
# columna 'genre_names'.

import json

def fix_quotes(x):
    if pd.isnull(x):
        return x
    try:
        return json.loads(x.replace("'", '"'))
    except json.JSONDecodeError:
        return []
        
moviesdf['genres'] = moviesdf['genres'].apply(fix_quotes)

def get_genre_name(genre_list):
    names = [genre['name'] for genre in genre_list]
    return '|'.join(names) if names else None

moviesdf['genre_names'] = moviesdf['genres'].apply(get_genre_name)

# %%
moviesdf.head()
# Out:
#    adult    budget                                             genres
# 0  False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  \
# 1  False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4  False         0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en  \
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title
# 0                    Toy Story  \
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview popularity  ... runtime
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943  ...    81.0  \
# 1  When siblings Judy and Peter discover an encha...  17.015539  ...   104.0
# 2  A family wedding reignites the ancient feud be...    11.7129  ...   101.0
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495  ...   127.0
# 4  Just when George Banks has recovered from his ...   8.387519  ...   106.0
#
#                                     spoken_languages    status
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released  \
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline
# 0                                                NaN  \
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0  \
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
#                   collection_name               genre_names
# 0            Toy Story Collection   Animation|Comedy|Family
# 1                            None  Adventure|Fantasy|Family
# 2       Grumpy Old Men Collection            Romance|Comedy
# 3                            None      Comedy|Drama|Romance
# 4  Father of the Bride Collection                    Comedy
#
# [5 rows x 25 columns]

# %%
# Con este ciclo se recorre cada fila de la columna "genre_names", luego para cada fila se valida si el valor en la columna "genre_names" 
# es diferente de None. Si el valor no es nulo, se divide el valor en una lista de géneros utilizando el carácter '|' como separador de elementos 
# y se guarda como la variable "genre_list". 

for genres in moviesdf['genre_names']:
    if genres is not None:
        genre_list = genres.split('|')
        for genre in genre_list:
            print(genre)
    else:
        print('No genres')

# %%
# Eliminamos la columna original
moviesdf.drop(columns=['genres'], inplace=True)

# %%
# Miramos los cambios realizados
moviesdf
# Out:
#        adult    budget                              homepage      id
# 0      False  30000000  http://toystory.disney.com/toy-story     862  \
# 1      False  65000000                                   NaN    8844
# 2      False         0                                   NaN   15602
# 3      False  16000000                                   NaN   31357
# 4      False         0                                   NaN   11862
# ...      ...       ...                                   ...     ...
# 45461  False         0  http://www.imdb.com/title/tt6209470/  439050
# 45462  False         0                                   NaN  111109
# 45463  False         0                                   NaN   67758
# 45464  False         0                                   NaN  227506
# 45465  False         0                                   NaN  461257
#
#          imdb_id original_language               original_title
# 0      tt0114709                en                    Toy Story  \
# 1      tt0113497                en                      Jumanji
# 2      tt0113228                en             Grumpier Old Men
# 3      tt0114885                en            Waiting to Exhale
# 4      tt0113041                en  Father of the Bride Part II
# ...          ...               ...                          ...
# 45461  tt6209470                fa                      رگ خواب
# 45462  tt2028550                tl          Siglo ng Pagluluwal
# 45463  tt0303758                en                     Betrayal
# 45464  tt0008536                en          Satana likuyushchiy
# 45465  tt6980792                en                     Queerama
#
#                                                 overview popularity
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943  \
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45461        Rising and falling between a man and woman.   0.072051
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                             poster_path  ... runtime
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...    81.0  \
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...   104.0
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...   101.0
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg  ...   127.0
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg  ...   106.0
# ...                                 ...  ...     ...
# 45461  /jldsYflnId4tTWPx8es3uzsB1I8.jpg  ...    90.0
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg  ...   360.0
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg  ...    90.0
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg  ...    87.0
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg  ...    75.0
#
#                                         spoken_languages    status
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released  \
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45461             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline
# 0                                                    NaN  \
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0  \
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45461                       Subdue  False          4.0        1.0
# 45462          Century of Birthing  False          9.0        3.0
# 45463                     Betrayal  False          3.8        6.0
# 45464             Satan Triumphant  False          0.0        0.0
# 45465                     Queerama  False          0.0        0.0
#
#                       collection_name               genre_names
# 0                Toy Story Collection   Animation|Comedy|Family
# 1                                None  Adventure|Fantasy|Family
# 2           Grumpy Old Men Collection            Romance|Comedy
# 3                                None      Comedy|Drama|Romance
# 4      Father of the Bride Collection                    Comedy
# ...                               ...                       ...
# 45461                            None              Drama|Family
# 45462                            None                     Drama
# 45463                            None     Action|Drama|Thriller
# 45464                            None                      None
# 45465                            None                      None
#
# [45466 rows x 24 columns]

# %%
# Se transforma la columna spoken_languages que contienen datos en formato json, luego definimos una función parse_json que acepta una cadena json (x), 
# intentamos parsearla a un objeto Jjson, para que devuelva el objeto si tiene éxito; si no, devuelve un diccionario vacío ({}). Después, la columna 
# "spoken_languages" se convierte utilizando esta función, es decir que se reemplazan los valores presentes en dicha columna que son 
# cadenas json con los respectivos objetos json producidos por parse_json.

def parse_json(x):
    try:
        return json.loads(x.replace("'", "\""))
    except:
        return {}

moviesdf["spoken_languages"] = moviesdf["spoken_languages"].apply(parse_json)

# Definimos una segunda función get_spoken_languages que espera un objeto json (x). Si el objeto es un diccionario vacío, devuelve la cadena "No languages", 
# de lo contrario, combina los nombres de idiomas contenidos en este objeto json en una sola cadena separada por "|" y devuelve esta cadena.

def get_spoken_languages(x):
    if x == {}:
        return "No languages"
    else:
        return "|".join([d["name"] for d in x])

moviesdf["spoken_languages"] = moviesdf["spoken_languages"].apply(get_spoken_languages)
print(moviesdf["spoken_languages"])
# Out:
# 0                 English
# 1        English|Français
# 2                 English
# 3                 English
# 4                 English
#                ...
# 45461               فارسی
# 45462
# 45463             English
# 45464
# 45465             English
# Name: spoken_languages, Length: 45466, dtype: object

# %%
# Miramos los cambios en el dataframe
moviesdf.head()
# Out:
#    adult    budget                              homepage     id    imdb_id
# 0  False  30000000  http://toystory.disney.com/toy-story    862  tt0114709  \
# 1  False  65000000                                   NaN   8844  tt0113497
# 2  False         0                                   NaN  15602  tt0113228
# 3  False  16000000                                   NaN  31357  tt0114885
# 4  False         0                                   NaN  11862  tt0113041
#
#   original_language               original_title
# 0                en                    Toy Story  \
# 1                en                      Jumanji
# 2                en             Grumpier Old Men
# 3                en            Waiting to Exhale
# 4                en  Father of the Bride Part II
#
#                                             overview popularity
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943  \
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                         poster_path  ... runtime  spoken_languages    status
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...    81.0           English  Released  \
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...   104.0  English|Français  Released
# 2  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...   101.0           English  Released
# 3  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg  ...   127.0           English  Released
# 4  /e64sOI48hQXyru7naBFyssKFxVd.jpg  ...   106.0           English  Released
#
#                                              tagline
# 0                                                NaN  \
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0  \
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
#                   collection_name               genre_names
# 0            Toy Story Collection   Animation|Comedy|Family
# 1                            None  Adventure|Fantasy|Family
# 2       Grumpy Old Men Collection            Romance|Comedy
# 3                            None      Comedy|Drama|Romance
# 4  Father of the Bride Collection                    Comedy
#
# [5 rows x 24 columns]

# %%
# Rellenamos los valores nulos de los campos revenue, budget con el número 0.
moviesdf['revenue'] = moviesdf['revenue'].fillna(0)
moviesdf['budget'] = moviesdf['budget'].fillna(0)

# %%
# Miramos el formaro del campo 'release_date'
moviesdf['release_date']
# Out:
# 0        1995-10-30
# 1        1995-12-15
# 2        1995-12-22
# 3        1995-12-22
# 4        1995-02-10
#             ...
# 45461           NaN
# 45462    2011-11-17
# 45463    2003-08-01
# 45464    1917-10-21
# 45465    2017-06-09
# Name: release_date, Length: 45466, dtype: object

# %%
# Miramos el número de valores nulos en la columna "release_date"
num_null = moviesdf['release_date'].isnull().sum()
num_null
# Out:
# 87

# %%
# Eliminamos todas las filas con valores nulos en la columna "release_date"
moviesdf.dropna(subset=['release_date'], inplace=True)

# %%
moviesdf.shape
# Out:
# (45379, 24)

# %%
# Miramos los cambios
moviesdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45379 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   adult                 45379 non-null  object
#  1   budget                45379 non-null  object
#  2   homepage              7769 non-null   object
#  3   id                    45379 non-null  object
#  4   imdb_id               45365 non-null  object
#  5   original_language     45368 non-null  object
#  6   original_title        45379 non-null  object
#  7   overview              44438 non-null  object
#  8   popularity            45377 non-null  object
#  9   poster_path           45040 non-null  object
#  10  production_companies  45379 non-null  object
#  11  production_countries  45379 non-null  object
#  12  release_date          45379 non-null  object
#  13  revenue               45379 non-null  float64
#  14  runtime               45130 non-null  float64
#  15  spoken_languages      45379 non-null  object
#  16  status                45296 non-null  object
#  17  tagline               20398 non-null  object
#  18  title                 45376 non-null  object
#  19  video                 45376 non-null  object
#  20  vote_average          45376 non-null  float64
#  21  vote_count            45376 non-null  float64
#  22  collection_name       3165 non-null   object
#  23  genre_names           42995 non-null  object
# dtypes: float64(4), object(20)
# memory usage: 8.7+ MB

# %%
# De haber fechas, deberán tener el formato AAAA-mm-dd, además deberán crear la columna release_year donde extraerán el año de la fecha de estreno.

# Convertimos la columna release_date en tipo datetime
moviesdf['release_date'] = pd.to_datetime(moviesdf['release_date'], errors='coerce')

# %%
# Verificamos que los valores de release_date estén en formato de fecha
print(moviesdf['release_date'].dt.strftime('%Y-%m-%d').head())
# Out:
# 0    1995-10-30
# 1    1995-12-15
# 2    1995-12-22
# 3    1995-12-22
# 4    1995-02-10
# Name: release_date, dtype: object

# %%
# Creamos una nueva columna release_year
moviesdf['release_year'] = moviesdf['release_date'].dt.year

# %%
# Validamos los cambios en el dataframe
moviesdf.head()
# Out:
#    adult    budget                              homepage     id    imdb_id
# 0  False  30000000  http://toystory.disney.com/toy-story    862  tt0114709  \
# 1  False  65000000                                   NaN   8844  tt0113497
# 2  False         0                                   NaN  15602  tt0113228
# 3  False  16000000                                   NaN  31357  tt0114885
# 4  False         0                                   NaN  11862  tt0113041
#
#   original_language               original_title
# 0                en                    Toy Story  \
# 1                en                      Jumanji
# 2                en             Grumpier Old Men
# 3                en            Waiting to Exhale
# 4                en  Father of the Bride Part II
#
#                                             overview popularity
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943  \
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                         poster_path  ...  spoken_languages    status
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...           English  Released  \
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...  English|Français  Released
# 2  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...           English  Released
# 3  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg  ...           English  Released
# 4  /e64sOI48hQXyru7naBFyssKFxVd.jpg  ...           English  Released
#
#                                              tagline
# 0                                                NaN  \
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0  \
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
#                   collection_name               genre_names release_year
# 0            Toy Story Collection   Animation|Comedy|Family       1995.0
# 1                            None  Adventure|Fantasy|Family       1995.0
# 2       Grumpy Old Men Collection            Romance|Comedy       1995.0
# 3                            None      Comedy|Drama|Romance       1995.0
# 4  Father of the Bride Collection                    Comedy       1995.0
#
# [5 rows x 25 columns]

# %%
# Convertimos la columna budget primero a tipo numérico para poder hacer el calculo con revenue
moviesdf['budget'] = pd.to_numeric(moviesdf['budget'], errors='coerce')

# %%
# Creamos la columna return
moviesdf['return'] = moviesdf.apply(lambda row: round(row['revenue'] / row['budget'], 2) if row['budget'] > 0 else 0, axis=1)

# %%
# Validamos los cambios realizados
moviesdf.head(5)
# Out:
#    adult      budget                              homepage     id    imdb_id
# 0  False  30000000.0  http://toystory.disney.com/toy-story    862  tt0114709  \
# 1  False  65000000.0                                   NaN   8844  tt0113497
# 2  False         0.0                                   NaN  15602  tt0113228
# 3  False  16000000.0                                   NaN  31357  tt0114885
# 4  False         0.0                                   NaN  11862  tt0113041
#
#   original_language               original_title
# 0                en                    Toy Story  \
# 1                en                      Jumanji
# 2                en             Grumpier Old Men
# 3                en            Waiting to Exhale
# 4                en  Father of the Bride Part II
#
#                                             overview popularity
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943  \
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                         poster_path  ...    status
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...  Released  \
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...  Released
# 2  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...  Released
# 3  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg  ...  Released
# 4  /e64sOI48hQXyru7naBFyssKFxVd.jpg  ...  Released
#
#                                              tagline
# 0                                                NaN  \
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video  vote_average vote_count
# 0                    Toy Story  False           7.7     5415.0  \
# 1                      Jumanji  False           6.9     2413.0
# 2             Grumpier Old Men  False           6.5       92.0
# 3            Waiting to Exhale  False           6.1       34.0
# 4  Father of the Bride Part II  False           5.7      173.0
#
#                   collection_name               genre_names release_year
# 0            Toy Story Collection   Animation|Comedy|Family       1995.0  \
# 1                            None  Adventure|Fantasy|Family       1995.0
# 2       Grumpy Old Men Collection            Romance|Comedy       1995.0
# 3                            None      Comedy|Drama|Romance       1995.0
# 4  Father of the Bride Collection                    Comedy       1995.0
#
#   return
# 0  12.45
# 1   4.04
# 2   0.00
# 3   5.09
# 4   0.00
#
# [5 rows x 26 columns]

# %%
# Eliminamos las columnas que no utilizaremos en el proyecto
moviesdf = moviesdf.drop(columns=['video', 'imdb_id', 'adult', 'original_title', 'vote_count', 'poster_path', 'homepage'])

# %%
# Validamos si se eliminaron las columnas
moviesdf.head(5)
# Out:
#        budget     id original_language
# 0  30000000.0    862                en  \
# 1  65000000.0   8844                en
# 2         0.0  15602                en
# 3  16000000.0  31357                en
# 4         0.0  11862                en
#
#                                             overview popularity
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943  \
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                                 production_companies
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]  \
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3  [{'name': 'Twentieth Century Fox Film Corporat...
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries release_date
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  \
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
#
#        revenue  runtime  spoken_languages    status
# 0  373554033.0     81.0           English  Released  \
# 1  262797249.0    104.0  English|Français  Released
# 2          0.0    101.0           English  Released
# 3   81452156.0    127.0           English  Released
# 4   76578911.0    106.0           English  Released
#
#                                              tagline
# 0                                                NaN  \
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  vote_average                 collection_name
# 0                    Toy Story           7.7            Toy Story Collection  \
# 1                      Jumanji           6.9                            None
# 2             Grumpier Old Men           6.5       Grumpy Old Men Collection
# 3            Waiting to Exhale           6.1                            None
# 4  Father of the Bride Part II           5.7  Father of the Bride Collection
#
#                 genre_names  release_year  return
# 0   Animation|Comedy|Family        1995.0   12.45
# 1  Adventure|Fantasy|Family        1995.0    4.04
# 2            Romance|Comedy        1995.0    0.00
# 3      Comedy|Drama|Romance        1995.0    5.09
# 4                    Comedy        1995.0    0.00

# %%
moviesdf.shape
# Out:
# (45379, 19)

# %%
# Funcion para obtener el nombre de los objetos anidados

def get_object_names(x):
    try:
        object_list = eval(x)
        object_names = [object_dict['name'] for object_dict in object_list]
        return ', '.join(object_names)
    except:
        return ''

# %%
# Creamos una nueva columna como nombre de los paises productores  
moviesdf['production_countries_names'] = moviesdf['production_countries'].apply(get_object_names)

# %%
# Creamos una nueva columna, como nombre produccion companias
moviesdf['production_companies_names'] = moviesdf['production_companies'].apply(get_object_names)

# %%
moviesdf.head(5)
# Out:
#        budget     id original_language
# 0  30000000.0    862                en  \
# 1  65000000.0   8844                en
# 2         0.0  15602                en
# 3  16000000.0  31357                en
# 4         0.0  11862                en
#
#                                             overview popularity
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943  \
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                                 production_companies
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]  \
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3  [{'name': 'Twentieth Century Fox Film Corporat...
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries release_date
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  \
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
#
#        revenue  runtime  ...    status
# 0  373554033.0     81.0  ...  Released  \
# 1  262797249.0    104.0  ...  Released
# 2          0.0    101.0  ...  Released
# 3   81452156.0    127.0  ...  Released
# 4   76578911.0    106.0  ...  Released
#
#                                              tagline
# 0                                                NaN  \
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title vote_average                 collection_name
# 0                    Toy Story          7.7            Toy Story Collection  \
# 1                      Jumanji          6.9                            None
# 2             Grumpier Old Men          6.5       Grumpy Old Men Collection
# 3            Waiting to Exhale          6.1                            None
# 4  Father of the Bride Part II          5.7  Father of the Bride Collection
#
#                 genre_names release_year  return  production_countries_names
# 0   Animation|Comedy|Family       1995.0   12.45    United States of America  \
# 1  Adventure|Fantasy|Family       1995.0    4.04    United States of America
# 2            Romance|Comedy       1995.0    0.00    United States of America
# 3      Comedy|Drama|Romance       1995.0    5.09    United States of America
# 4                    Comedy       1995.0    0.00    United States of America
#
#                           production_companies_names
# 0                            Pixar Animation Studios
# 1  TriStar Pictures, Teitler Film, Interscope Com...
# 2                       Warner Bros., Lancaster Gate
# 3             Twentieth Century Fox Film Corporation
# 4         Sandollar Productions, Touchstone Pictures
#
# [5 rows x 21 columns]

# %%
# Eliminamos estas columnas, porque ya fueron transformadas y nombradas como production_countries_names
moviesdf = moviesdf.drop('production_countries', axis=1)

# %%
# Eliminamos estas columnas, porque ya fueron transformadas y nombradas como production_companies_names
moviesdf = moviesdf.drop('production_companies', axis=1)

# %%
moviesdf.head(5)
# Out:
#        budget     id original_language
# 0  30000000.0    862                en  \
# 1  65000000.0   8844                en
# 2         0.0  15602                en
# 3  16000000.0  31357                en
# 4         0.0  11862                en
#
#                                             overview popularity release_date
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943   1995-10-30  \
# 1  When siblings Judy and Peter discover an encha...  17.015539   1995-12-15
# 2  A family wedding reignites the ancient feud be...    11.7129   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495   1995-12-22
# 4  Just when George Banks has recovered from his ...   8.387519   1995-02-10
#
#        revenue  runtime  spoken_languages    status
# 0  373554033.0     81.0           English  Released  \
# 1  262797249.0    104.0  English|Français  Released
# 2          0.0    101.0           English  Released
# 3   81452156.0    127.0           English  Released
# 4   76578911.0    106.0           English  Released
#
#                                              tagline
# 0                                                NaN  \
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  vote_average                 collection_name
# 0                    Toy Story           7.7            Toy Story Collection  \
# 1                      Jumanji           6.9                            None
# 2             Grumpier Old Men           6.5       Grumpy Old Men Collection
# 3            Waiting to Exhale           6.1                            None
# 4  Father of the Bride Part II           5.7  Father of the Bride Collection
#
#                 genre_names  release_year  return production_countries_names
# 0   Animation|Comedy|Family        1995.0   12.45   United States of America  \
# 1  Adventure|Fantasy|Family        1995.0    4.04   United States of America
# 2            Romance|Comedy        1995.0    0.00   United States of America
# 3      Comedy|Drama|Romance        1995.0    5.09   United States of America
# 4                    Comedy        1995.0    0.00   United States of America
#
#                           production_companies_names
# 0                            Pixar Animation Studios
# 1  TriStar Pictures, Teitler Film, Interscope Com...
# 2                       Warner Bros., Lancaster Gate
# 3             Twentieth Century Fox Film Corporation
# 4         Sandollar Productions, Touchstone Pictures

# %%
moviesdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45379 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   budget                      45376 non-null  float64
#  1   id                          45379 non-null  object
#  2   original_language           45368 non-null  object
#  3   overview                    44438 non-null  object
#  4   popularity                  45377 non-null  object
#  5   release_date                45376 non-null  datetime64[ns]
#  6   revenue                     45379 non-null  float64
#  7   runtime                     45130 non-null  float64
#  8   spoken_languages            45379 non-null  object
#  9   status                      45296 non-null  object
#  10  tagline                     20398 non-null  object
#  11  title                       45376 non-null  object
#  12  vote_average                45376 non-null  float64
#  13  collection_name             3165 non-null   object
#  14  genre_names                 42995 non-null  object
#  15  release_year                45376 non-null  float64
#  16  return                      45379 non-null  float64
#  17  production_countries_names  45379 non-null  object
#  18  production_companies_names  45379 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(12)
# memory usage: 6.9+ MB

# %%
print(moviesdf['release_date'].dtype)
# Out:
# datetime64[ns]

# %%
# Por ultimo convertimos nuestro dataframe ya transformado a un nuevo archivo .csv para trabajarlo en el archivo main.py 
moviesdf = pd.DataFrame(moviesdf)
moviesdf.to_csv("df.csv")
